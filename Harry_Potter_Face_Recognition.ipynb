# %% [markdown]
# ### Harry Potter Actors Face Recognition
#
# In this colab, harry potter face recognition will be implemented using transfer learning
#
# * First, we will use feature extraction transfer learning
# * Second, we will use fine-tuning transfer learning
#
# You can see all the steps that we will take sequentially below:
#
# 1. Import all necessary data and plot them to visualize
# 2. Preprocess the image for model that we will create
# 3. Create feature extraction model
# 4. Compile the model
# 5. Fit the model
# 6. Evaluate the model
# 7. Implement fine-tuning transfer learning upon feature extration
#
# **NOTE :** In this colab, we will use two callbacks:
# 1. ModelCheckpoint callback
# 2. Tensorboard callback
#
# **NOTE :** In this colab, To simplify understanding we will import predefined methods *helper_functions.py" to help us throughout the model implementing steps

# %% [markdown]
# ### 1. Import all necessary data and plot them to visualize

# %%
import tensorflow as tf
from helper_functions import walk_through_dir,view_random_image,plot_loss_curves,pred_and_plot,create_tensorboard_callback,load_and_prep_image

# import necessary data to colab
train_dir = "/content/drive/MyDrive/Data/harry_potter/Train"
test_dir = "/content/drive/MyDrive/Data/harry_potter/Test"

# Set up data inputs
train_data = tf.keras.preprocessing.image_dataset_from_directory(train_dir,
                                                                 label_mode="categorical",
                                                                 image_size=(224,224),
                                                                 batch_size=32
                                                                 )

test_data = tf.keras.preprocessing.image_dataset_from_directory(test_dir,
                                                                 label_mode="categorical",
                                                                 image_size=(224,224),
                                                                 batch_size=32
                                                                 )

# create the class_names for future steps
class_names=train_data.class_names;
# Out:
# Found 192 files belonging to 16 classes.
# Found 106 files belonging to 16 classes.

# %%
# let's control How many images we have
walk_through_dir("/content/drive/MyDrive/Data/harry_potter")
# Out:
# There are 2 directories and 0 images in '/content/drive/MyDrive/Data/harry_potter'.
# There are 16 directories and 0 images in '/content/drive/MyDrive/Data/harry_potter/Train'.
# There are 0 directories and 12 images in '/content/drive/MyDrive/Data/harry_potter/Train/Julie Walters'.
# There are 0 directories and 14 images in '/content/drive/MyDrive/Data/harry_potter/Train/Maggie Smith'.
# There are 0 directories and 11 images in '/content/drive/MyDrive/Data/harry_potter/Train/Mark Williams'.
# There are 0 directories and 12 images in '/content/drive/MyDrive/Data/harry_potter/Train/Matthew Lewis'.
# There are 0 directories and 13 images in '/content/drive/MyDrive/Data/harry_potter/Train/Michael Gambon'.
# There are 0 directories and 9 images in '/content/drive/MyDrive/Data/harry_potter/Train/Rupert Grint'.
# There are 0 directories and 8 images in '/content/drive/MyDrive/Data/harry_potter/Train/Tom Felton'.
# There are 0 directories and 13 images in '/content/drive/MyDrive/Data/harry_potter/Train/Ralph Fiennes'.
# There are 0 directories and 13 images in '/content/drive/MyDrive/Data/harry_potter/Train/Robbie Coltrane'.
# There are 0 directories and 14 images in '/content/drive/MyDrive/Data/harry_potter/Train/Helena Bonham Carter'.
# There are 0 directories and 11 images in '/content/drive/MyDrive/Data/harry_potter/Train/Emma Watson'.
# There are 0 directories and 16 images in '/content/drive/MyDrive/Data/harry_potter/Train/Evanna Lynch'.
# There are 0 directories and 13 images in '/content/drive/MyDrive/Data/harry_potter/Train/Alan Rickman'.
# There are 0 directories and 12 images in '/content/drive/MyDrive/Data/harry_potter/Train/Daniel Radcliffe'.
# There are 0 directories and 9 images in '/content/drive/MyDrive/Data/harry_potter/Train/Bonnie Wright'.
# There are 0 directories and 12 images in '/content/drive/MyDrive/Data/harry_potter/Train/Alfred Enoch'.
# There are 16 directories and 0 images in '/content/drive/MyDrive/Data/harry_potter/Test'.
# There are 0 directories and 4 images in '/content/drive/MyDrive/Data/harry_potter/Test/Tom Felton'.
# There are 0 directories and 5 images in '/content/drive/MyDrive/Data/harry_potter/Test/Rupert Grint'.
# There are 0 directories and 7 images in '/content/drive/MyDrive/Data/harry_potter/Test/Ralph Fiennes'.
# There are 0 directories and 6 images in '/content/drive/MyDrive/Data/harry_potter/Test/Robbie Coltrane'.
# There are 0 directories and 11 images in '/content/drive/MyDrive/Data/harry_potter/Test/Evanna Lynch'.
# There are 0 directories and 8 images in '/content/drive/MyDrive/Data/harry_potter/Test/Helena Bonham Carter'.
# There are 0 directories and 8 images in '/content/drive/MyDrive/Data/harry_potter/Test/Maggie Smith'.
# There are 0 directories and 5 images in '/content/drive/MyDrive/Data/harry_potter/Test/Bonnie Wright'.
# There are 0 directories and 6 images in '/content/drive/MyDrive/Data/harry_potter/Test/Julie Walters'.
# There are 0 directories and 6 images in '/content/drive/MyDrive/Data/harry_potter/Test/Mark Williams'.
# There are 0 directories and 7 images in '/content/drive/MyDrive/Data/harry_potter/Test/Michael Gambon'.
# There are 0 directories and 6 images in '/content/drive/MyDrive/Data/harry_potter/Test/Daniel Radcliffe'.
# There are 0 directories and 9 images in '/content/drive/MyDrive/Data/harry_potter/Test/Emma Watson'.
# There are 0 directories and 6 images in '/content/drive/MyDrive/Data/harry_potter/Test/Matthew Lewis'.
# There are 0 directories and 6 images in '/content/drive/MyDrive/Data/harry_potter/Test/Alfred Enoch'.
# There are 0 directories and 6 images in '/content/drive/MyDrive/Data/harry_potter/Test/Alan Rickman'.

# %% [markdown]
# ### 2. Preprocess the image for model that we will create

# %%
# For preprocessing and for preventing overfitting, let's augment the data
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.models import Sequential

# build data augmentation layer
data_augmentation = Sequential([
    preprocessing.RandomFlip("horizontal"),
    preprocessing.RandomHeight(0.2),
    preprocessing.RandomWidth(0.2),
    preprocessing.RandomRotation(0.2),
    # preprocessing.Rescaling(1./255) # if you are using a model such as ResNet50V2, you'll need to rescale your data
], name="Data_augmentation")

# %% [markdown]
# ### 3. Create feature extraction model

# %%
# setup the input shape to our model
input_shape=(224,224,3)

# cretae a frozen base model (also called backbone)
base_model = tf.keras.applications.EfficientNetB7(include_top=False)
base_model.trainable=False

# create the inputs and outputs (including the layers between)
inputs = layers.Input(shape=input_shape,name="Input_layer")
x = data_augmentation(inputs)
x = base_model(x,training=False)
x = layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)
outputs=layers.Dense(16,activation="softmax",name="output_layer")(x)
model=tf.keras.Model(inputs,outputs)

# %% [markdown]
# ### 4. Compile the model

# %%
# compile the model (and whenever model is changed)
model.compile(
    loss = "categorical_crossentropy",
    optimizer=tf.keras.optimizers.Adam(),
    metrics=["accuracy"]
)

# %%
# let's see the model architecture
model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  Data_augmentation (Sequenti  (None, None, None, 3)    0
#  al)
#
#  efficientnetb7 (Functional)  (None, None, None, 2560)  64097687
#
#  global_average_pooling_laye  (None, 2560)             0
#  r (GlobalAveragePooling2D)
#
#  output_layer (Dense)        (None, 16)                40976
#
# =================================================================
# Total params: 64,138,663
# Trainable params: 40,976
# Non-trainable params: 64,097,687
# _________________________________________________________________

# %% [markdown]
# Creating a ModelCheckpoint callback

# %%
# set checkpoint path
chck_path = "harry_potter_ckpt"

# create a modelcheckpoint callback that saves the model's weight only
chck_callback = tf.keras.callbacks.ModelCheckpoint(filepath=chck_path,
                                                   save_weights_only=True,
                                                   save_best_only=False,
                                                   save_freq="epoch",# save every epoch
                                                   verbose=1 # to see its going
                                                   )

# %% [markdown]
# ### 5. Fit the model

# %%
# fit the model saving checkpoints every epoch
initial_epoch=20

# fit the model
hist_1 = model.fit(train_data,
                   epochs=initial_epoch,
                   steps_per_epoch=len(train_data),
                   validation_data=test_data,
                   validation_steps=len(test_data),
                   # Track model training loss and accuracy
                   callbacks=[create_tensorboard_callback(dir_name="transfer_learning",
                                                            experiment_name="harry_potter_actors_face_recognition_feature_extraction"),
                                chck_callback]
                   )
# Out:
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Unable to serialize [2.0896919 2.1128857 2.1081853] to JSON. Unrecognized type <class 'tensorflow.python.framework.ops.EagerTensor'>.
# Saving TensorBoard log files to: transfer_learning/harry_potter_actors_face_recognition_feature_extraction/20230905-143917
# Epoch 1/20
# 6/6 [==============================] - ETA: 0s - loss: 0.5006 - accuracy: 0.9219
# Epoch 1: saving model to harry_potter_ckpt
# 6/6 [==============================] - 89s 5s/step - loss: 0.5006 - accuracy: 0.9219 - val_loss: 1.2187 - val_accuracy: 0.6415
# Epoch 2/20
# 6/6 [==============================] - ETA: 0s - loss: 0.1708 - accuracy: 0.9896
# Epoch 2: saving model to harry_potter_ckpt
# 6/6 [==============================] - 18s 3s/step - loss: 0.1708 - accuracy: 0.9896 - val_loss: 1.1805 - val_accuracy: 0.6509
# Epoch 3/20
# 6/6 [==============================] - ETA: 0s - loss: 0.0744 - accuracy: 0.9896
# Epoch 3: saving model to harry_potter_ckpt
# 6/6 [==============================] - 18s 3s/step - loss: 0.0744 - accuracy: 0.9896 - val_loss: 1.1386 - val_accuracy: 0.6415
# Epoch 4/20
# 6/6 [==============================] - ETA: 0s - loss: 0.0576 - accuracy: 0.9896
# Epoch 4: saving model to harry_potter_ckpt
# 6/6 [==============================] - 13s 2s/step - loss: 0.0576 - accuracy: 0.9896 - val_loss: 1.2159 - val_accuracy: 0.6415
# Epoch 5/20
# 6/6 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.9948
# Epoch 5: saving model to harry_potter_ckpt
# 6/6 [==============================] - 16s 3s/step - loss: 0.0278 - accuracy: 0.9948 - val_loss: 1.3618 - val_accuracy: 0.6321
# Epoch 6/20
# 6/6 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.9948
# Epoch 6: saving model to harry_potter_ckpt
# 6/6 [==============================] - 15s 2s/step - loss: 0.0314 - accuracy: 0.9948 - val_loss: 1.2272 - val_accuracy: 0.6604
# Epoch 7/20
# 6/6 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 7: saving model to harry_potter_ckpt
# 6/6 [==============================] - 13s 2s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.2771 - val_accuracy: 0.6698
# Epoch 8/20
# 6/6 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9896
# Epoch 8: saving model to harry_potter_ckpt
# 6/6 [==============================] - 13s 2s/step - loss: 0.0188 - accuracy: 0.9896 - val_loss: 1.3942 - val_accuracy: 0.6321
# Epoch 9/20
# 6/6 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9896
# Epoch 9: saving model to harry_potter_ckpt
# 6/6 [==============================] - 14s 2s/step - loss: 0.0241 - accuracy: 0.9896 - val_loss: 1.4784 - val_accuracy: 0.6415
# Epoch 10/20
# 6/6 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9844
# Epoch 10: saving model to harry_potter_ckpt
# 6/6 [==============================] - 18s 3s/step - loss: 0.0397 - accuracy: 0.9844 - val_loss: 1.2903 - val_accuracy: 0.6509
# Epoch 11/20
# 6/6 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9948
# Epoch 11: saving model to harry_potter_ckpt
# 6/6 [==============================] - 27s 5s/step - loss: 0.0182 - accuracy: 0.9948 - val_loss: 1.2675 - val_accuracy: 0.6698
# Epoch 12/20
# 6/6 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 12: saving model to harry_potter_ckpt
# 6/6 [==============================] - 25s 5s/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.3231 - val_accuracy: 0.6698
# Epoch 13/20
# 6/6 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 13: saving model to harry_potter_ckpt
# 6/6 [==============================] - 22s 4s/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 1.3730 - val_accuracy: 0.6792
# Epoch 14/20
# 6/6 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 14: saving model to harry_potter_ckpt
# 6/6 [==============================] - 28s 5s/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.3861 - val_accuracy: 0.6509
# Epoch 15/20
# 6/6 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 1.0000
# Epoch 15: saving model to harry_potter_ckpt
# 6/6 [==============================] - 23s 4s/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 1.3774 - val_accuracy: 0.6132
# Epoch 16/20
# 6/6 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 1.0000
# Epoch 16: saving model to harry_potter_ckpt
# 6/6 [==============================] - 24s 4s/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 1.4477 - val_accuracy: 0.6226
# Epoch 17/20
# 6/6 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 0.9948
# Epoch 17: saving model to harry_potter_ckpt
# 6/6 [==============================] - 21s 4s/step - loss: 0.0209 - accuracy: 0.9948 - val_loss: 1.4259 - val_accuracy: 0.6415
# Epoch 18/20
# 6/6 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 18: saving model to harry_potter_ckpt
# 6/6 [==============================] - 23s 4s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.4619 - val_accuracy: 0.6604
# Epoch 19/20
# 6/6 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9948
# Epoch 19: saving model to harry_potter_ckpt
# 6/6 [==============================] - 24s 4s/step - loss: 0.0086 - accuracy: 0.9948 - val_loss: 1.4128 - val_accuracy: 0.6698
# Epoch 20/20
# 6/6 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 20: saving model to harry_potter_ckpt
# 6/6 [==============================] - 24s 4s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.4078 - val_accuracy: 0.6509

# %% [markdown]
# Looks like our model is not good enough
# * Let's evaluate model and make some predictions with it

# %% [markdown]
# ## 6. Evaluate the model

# %%
results_1=model.evaluate(test_data)
# Out:
# 4/4 [==============================] - 2s 278ms/step - loss: 1.4078 - accuracy: 0.6509

# %%
plot_loss_curves(hist_1)

# %%
filename = "/content/drive/MyDrive/Data/harry_potter/Test/Julie Walters/Julie Walters (12).jpg"
pred_and_plot(model,filename,class_names)
# Out:
# 1/1 [==============================] - 6s 6s/step

# %% [markdown]
# ### 7. Implement fine-tuning transfer learning upon feature extration

# %%
len(base_model.layers)
# Out:
# 814

# %%
# To begin with fine-tuning, let's start by setting the last 10 layers of our base_model.trainable = True
base_model.trainable=True

# Freeze all layers except for the last 200
for layer in base_model.layers[:-200]:
  layer.trainable=False

# Recompile (we have to recompile our models every time we make a change)
model.compile(loss="categorical_crossentropy",
                optimizer=tf.keras.optimizers.Adam(learning_rate = 0.0001), # for fine-tuning rule you want to lower your learning_rate by 10x
                metrics=["accuracy"]
                )

# Fine tune for another 5 epochs
fine_tune_epochs = initial_epoch + 20

# Refit the model (same as model_2 except with more trainable layers)
hist_2 = model.fit(train_data,
                     epochs=fine_tune_epochs,
                     steps_per_epoch=len(train_data),
                     validation_data=test_data,
                     validation_steps=len(test_data),
                     initial_epoch = hist_1.epoch[-1], # start training from previouslast epoch
                     callbacks=[create_tensorboard_callback(dir_name="transfer_learning",
                                                            experiment_name="harry_potter_actors_face_recognition_fine_tuning"),
                                chck_callback]
                     )
# Out:
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Unable to serialize [2.0896919 2.1128857 2.1081853] to JSON. Unrecognized type <class 'tensorflow.python.framework.ops.EagerTensor'>.
# Saving TensorBoard log files to: transfer_learning/harry_potter_actors_face_recognition_fine_tuning/20230905-145044
# Epoch 20/40
# 6/6 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 20: saving model to harry_potter_ckpt
# 6/6 [==============================] - 91s 7s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.4431 - val_accuracy: 0.6792
# Epoch 21/40
# 6/6 [==============================] - ETA: 0s - loss: 3.3235e-04 - accuracy: 1.0000
# Epoch 21: saving model to harry_potter_ckpt
# 6/6 [==============================] - 28s 5s/step - loss: 3.3235e-04 - accuracy: 1.0000 - val_loss: 1.7241 - val_accuracy: 0.6981
# Epoch 22/40
# 6/6 [==============================] - ETA: 0s - loss: 6.4942e-04 - accuracy: 1.0000
# Epoch 22: saving model to harry_potter_ckpt
# 6/6 [==============================] - 33s 6s/step - loss: 6.4942e-04 - accuracy: 1.0000 - val_loss: 2.0332 - val_accuracy: 0.6604
# Epoch 23/40
# 6/6 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 23: saving model to harry_potter_ckpt
# 6/6 [==============================] - 27s 5s/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.8913 - val_accuracy: 0.6887
# Epoch 24/40
# 6/6 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 24: saving model to harry_potter_ckpt
# 6/6 [==============================] - 31s 6s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.1909 - val_accuracy: 0.6509
# Epoch 25/40
# 6/6 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9948
# Epoch 25: saving model to harry_potter_ckpt
# 6/6 [==============================] - 32s 6s/step - loss: 0.0081 - accuracy: 0.9948 - val_loss: 2.1041 - val_accuracy: 0.6604
# Epoch 26/40
# 6/6 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 26: saving model to harry_potter_ckpt
# 6/6 [==============================] - 27s 5s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.8098 - val_accuracy: 0.6981
# Epoch 27/40
# 6/6 [==============================] - ETA: 0s - loss: 3.5450e-04 - accuracy: 1.0000
# Epoch 27: saving model to harry_potter_ckpt
# 6/6 [==============================] - 25s 4s/step - loss: 3.5450e-04 - accuracy: 1.0000 - val_loss: 1.7214 - val_accuracy: 0.7075
# Epoch 28/40
# 6/6 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 28: saving model to harry_potter_ckpt
# 6/6 [==============================] - 29s 5s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.7939 - val_accuracy: 0.6887
# Epoch 29/40
# 6/6 [==============================] - ETA: 0s - loss: 7.6614e-04 - accuracy: 1.0000
# Epoch 29: saving model to harry_potter_ckpt
# 6/6 [==============================] - 22s 4s/step - loss: 7.6614e-04 - accuracy: 1.0000 - val_loss: 1.9184 - val_accuracy: 0.6792
# Epoch 30/40
# 6/6 [==============================] - ETA: 0s - loss: 7.4201e-04 - accuracy: 1.0000
# Epoch 30: saving model to harry_potter_ckpt
# 6/6 [==============================] - 32s 6s/step - loss: 7.4201e-04 - accuracy: 1.0000 - val_loss: 1.8406 - val_accuracy: 0.6792
# Epoch 31/40
# 6/6 [==============================] - ETA: 0s - loss: 1.7175e-04 - accuracy: 1.0000
# Epoch 31: saving model to harry_potter_ckpt
# 6/6 [==============================] - 27s 5s/step - loss: 1.7175e-04 - accuracy: 1.0000 - val_loss: 1.8416 - val_accuracy: 0.6981
# Epoch 32/40
# 6/6 [==============================] - ETA: 0s - loss: 5.4612e-04 - accuracy: 1.0000
# Epoch 32: saving model to harry_potter_ckpt
# 6/6 [==============================] - 26s 5s/step - loss: 5.4612e-04 - accuracy: 1.0000 - val_loss: 1.7788 - val_accuracy: 0.7075
# Epoch 33/40
# 6/6 [==============================] - ETA: 0s - loss: 3.3963e-04 - accuracy: 1.0000
# Epoch 33: saving model to harry_potter_ckpt
# 6/6 [==============================] - 29s 5s/step - loss: 3.3963e-04 - accuracy: 1.0000 - val_loss: 1.7673 - val_accuracy: 0.7264
# Epoch 34/40
# 6/6 [==============================] - ETA: 0s - loss: 3.0947e-05 - accuracy: 1.0000
# Epoch 34: saving model to harry_potter_ckpt
# 6/6 [==============================] - 27s 5s/step - loss: 3.0947e-05 - accuracy: 1.0000 - val_loss: 1.7746 - val_accuracy: 0.7170
# Epoch 35/40
# 6/6 [==============================] - ETA: 0s - loss: 8.2209e-05 - accuracy: 1.0000
# Epoch 35: saving model to harry_potter_ckpt
# 6/6 [==============================] - 27s 5s/step - loss: 8.2209e-05 - accuracy: 1.0000 - val_loss: 1.7806 - val_accuracy: 0.7264
# Epoch 36/40
# 6/6 [==============================] - ETA: 0s - loss: 3.9650e-05 - accuracy: 1.0000
# Epoch 36: saving model to harry_potter_ckpt
# 6/6 [==============================] - 23s 4s/step - loss: 3.9650e-05 - accuracy: 1.0000 - val_loss: 1.7829 - val_accuracy: 0.7264
# Epoch 37/40
# 6/6 [==============================] - ETA: 0s - loss: 9.9447e-05 - accuracy: 1.0000
# Epoch 37: saving model to harry_potter_ckpt
# 6/6 [==============================] - 27s 5s/step - loss: 9.9447e-05 - accuracy: 1.0000 - val_loss: 1.7856 - val_accuracy: 0.7358
# Epoch 38/40
# 6/6 [==============================] - ETA: 0s - loss: 4.4532e-05 - accuracy: 1.0000
# Epoch 38: saving model to harry_potter_ckpt
# 6/6 [==============================] - 21s 4s/step - loss: 4.4532e-05 - accuracy: 1.0000 - val_loss: 1.7910 - val_accuracy: 0.7358
# Epoch 39/40
# 6/6 [==============================] - ETA: 0s - loss: 2.3148e-05 - accuracy: 1.0000
# Epoch 39: saving model to harry_potter_ckpt
# 6/6 [==============================] - 23s 4s/step - loss: 2.3148e-05 - accuracy: 1.0000 - val_loss: 1.7927 - val_accuracy: 0.7358
# Epoch 40/40
# 6/6 [==============================] - ETA: 0s - loss: 6.7200e-05 - accuracy: 1.0000
# Epoch 40: saving model to harry_potter_ckpt
# 6/6 [==============================] - 23s 4s/step - loss: 6.7200e-05 - accuracy: 1.0000 - val_loss: 1.7955 - val_accuracy: 0.7264

# %%
model.evaluate(test_data)
# Out:
# 4/4 [==============================] - 2s 284ms/step - loss: 1.7955 - accuracy: 0.7264
# [1.795462727546692, 0.7264150977134705]

# %%
plot_loss_curves(hist_2)
